# %%
# !pip install "numpy<2.0.0"
# Then restart terminal
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy<2.0.0
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 92.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
# Successfully installed numpy-1.26.4

# %%
# !pip install -qq medmnist
# !pip install -qq av
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/ubuntu/.local/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from opencv-python) (1.26.4)

# %%
import sys
sys.path.append('/home/ubuntu/.lambda/lib/python3.10/site-packages')

# %%
import os
import cv2
import numpy as np
import tensorflow as tf  # for data preprocessing only
import keras
import av
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# 2025-02-14 18:50:55.746729: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-14 18:50:55.758936: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739559055.773703    2527 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739559055.778135    2527 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-14 18:50:55.792702: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
DATA_DIR = 'HandWashDataset'

CLASSES = ['Step_1', 'Step_2_Left', 'Step_2_Right', 'Step_3', 
           'Step_4_Left', 'Step_4_Right', 'Step_5_Left', 'Step_5_Right', 
           'Step_6_Left', 'Step_6_Right', 'Step_7_Left', 'Step_7_Right']

LABELS_TO_ID = { 'Step_1' : 0, 'Step_2_Left' : 1, 'Step_2_Right' : 1, 
                'Step_3' : 2, 'Step_4_Left' : 3, 'Step_4_Right' : 3, 
                'Step_5_Left' : 4, 'Step_5_Right' : 4, 'Step_6_Left' : 5,
                'Step_6_Right' : 5, 'Step_7_Left' : 6, 'Step_7_Right' : 6}

ACTUAL_CLASSES = [1, 2, 3, 4, 5, 6, 7]

# LABELS_TO_ID = { label : i for i, label in enumerate(CLASSES) }

TEST_SIZE = 0.2
VAL_SIZE = 0.2
DATASET_SEED = 81

FRAME_SIZE = (360, 240)
SCALE = 255.0
CLIP_LENGTH = 60 # 120 runs into errors

INPUT_SHAPE = (210, 270, 1) # coordinates are inverted for some reason
NUM_FRAMES = 3

# TRAINING
BATCH_SIZE = 32 # down from 64 because of frame size
NUM_CLASSES = len(ACTUAL_CLASSES)
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5
EPOCHS = 400

# %%
def prepare_dataset(data_dir, classes, test_size=TEST_SIZE, val_size=VAL_SIZE, random_state=DATASET_SEED):
    video_lengths = []
    for class_name in classes:
        class_dir = os.path.join(data_dir, class_name)
        videos = os.listdir(class_dir)
        for video_file in videos:
            if os.path.isdir(video_file):
                continue
            video_path = os.path.join(class_dir, video_file)
            video_reader = cv2.VideoCapture(video_path)
            frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
            video_lengths.append((class_name, video_path, frames_count))
            video_reader.release()

    train_videos, test_val_videos = train_test_split(video_lengths, test_size=test_size+val_size, random_state=random_state)
    val_videos, test_videos = train_test_split(test_val_videos, test_size=test_size/(test_size+val_size), random_state=random_state)

    return train_videos, val_videos, test_videos

# %%
def read_video_pyav(container, indices, new_size = FRAME_SIZE, scale=SCALE):
    '''Decode the video with PyAV decoder.
    Args:
        container (`av.container.input.InputContainer`): PyAV container.
        indices (`List[int]`): List of frame indices to decode.
    Returns:
        result (np.ndarray): np array of decoded frames of shape (num_frames, height, width, 3).'''
    frames = []
    container.seek(0)
    start_index = indices[0]
    end_index = indices[-1]
    for i, frame in enumerate(container.decode(video=0)):
        if i > end_index:
            break
        if i >= start_index and i in indices:
            new_frame = frame.to_ndarray(format="rgb24")
            new_frame = cv2.cvtColor(new_frame, cv2.COLOR_RGB2GRAY)
            new_frame = new_frame / scale
            new_frame = cv2.resize(new_frame, new_size)
            frames.append(new_frame)
    return np.stack(frames)

def sample_frame_indices(frame_sample_rate, seg_len, clip_len=CLIP_LENGTH):
    '''Sample a given number of frame indices from the video.
    Args:
        clip_len (`int`): Total number of frames to sample.
        frame_sample_rate (`int`): Sample every n-th frame.
        seg_len (`int`): Maximum allowed index of sample's last frame.
    Returns:
        indices (`List[int]`): List of sampled frame indices'''
    converted_len = int(clip_len * frame_sample_rate)
    # end_idx = np.random.randint(converted_len, seg_len)
    end_idx = seg_len # Always picking the last CLIP_LENGTH many frames
    start_idx = end_idx - converted_len
    indices = np.linspace(start_idx, end_idx, num=clip_len)
    indices = np.clip(indices, start_idx, end_idx - 1).astype(np.int64)
    return indices

def download_and_prepare_dataset(video_directories: list):
    """Utility function to download dataset
    Arguments:
        list of addresses of videos
    Returns:
        list of videos, each of different dimension"""
    np_videos = []
    for address in video_directories:
        vid_container = av.open(address)
        vid_indices = sample_frame_indices(frame_sample_rate=1, seg_len=vid_container.streams.video[0].frames)
        np_videos.append(read_video_pyav(container=vid_container, indices=vid_indices))
    return np_videos

def preprocess_dataset(list_of_videos, list_of_labels, new_size=FRAME_SIZE, clip_len=CLIP_LENGTH):
    """Normalize and resize the dataset"""
    clips = clip_len // NUM_FRAMES
    resized_list = np.zeros((len(list_of_videos) * clips, NUM_FRAMES, FRAME_SIZE[1], FRAME_SIZE[0]), dtype=np.float32)
    resized_labels = np.zeros((len(list_of_videos) * clips), dtype = np.float32)
    for i, video in enumerate(list_of_videos):
        for j, frame in enumerate(video):
            clip_num = ((i * CLIP_LENGTH) + j) // 3
            if j % 3 == 0:
                resized_labels[clip_num] = list_of_labels[i]
            resized_list[clip_num][j % 3] = frame
            
    return (resized_list, resized_labels)

# %%
train_info, val_info, test_info = prepare_dataset(DATA_DIR, CLASSES)

train_addr = [info[1] for info in train_info]
train_names = [LABELS_TO_ID[info[0]] for info in train_info]

val_addr = [info[1] for info in val_info]
val_names = [LABELS_TO_ID[info[0]] for info in val_info]

test_addr = [info[1] for info in test_info]
test_names = [LABELS_TO_ID[info[0]] for info in test_info]

# %%
train_videos, train_labels = preprocess_dataset(download_and_prepare_dataset(train_addr), train_names)
print("done with train")
val_videos, val_labels = preprocess_dataset(download_and_prepare_dataset(val_addr), val_names)
print("done with val")
test_videos, test_labels = preprocess_dataset(download_and_prepare_dataset(test_addr), test_names)
# Out:
# done with train
# done with val

# %%
def preprocess(frame: tf.Tensor, label: tf.Tensor):
    """Preprocess the frames tensors and parse the labels."""
    frame = frame[..., tf.newaxis]
    frame = tf.image.random_crop(frame, size=(NUM_FRAMES, INPUT_SHAPE[0], INPUT_SHAPE[1], INPUT_SHAPE[2]))
    frame = tf.image.random_flip_up_down(frame)
    frame = tf.image.random_brightness(frame, 0.2)
    return frame, label

def prepare_dataloader(
    videos: np.ndarray,
    labels: np.ndarray,
    loader_type: str = "train",
    batch_size: int = BATCH_SIZE,
):
    """Utility function to prepare the dataloader."""
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    return dataloader

# %%
trainloader = prepare_dataloader(train_videos, train_labels, "train")
validloader = prepare_dataloader(val_videos, val_labels, "valid")
testloader = prepare_dataloader(test_videos, test_labels, "test")
# Out:
# I0000 00:00:1739559396.602206    2527 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20732 MB memory:  -> device: 0, name: NVIDIA A10, pci bus id: 0000:07:00.0, compute capability: 8.6

# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, TimeDistributed, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical

# %%
print(NUM_CLASSES)
# Out:
# 7

# %%
new_input = (NUM_FRAMES, INPUT_SHAPE[0], INPUT_SHAPE[1], INPUT_SHAPE[2])

model = Sequential([
    TimeDistributed(Conv2D(48, (7, 7), activation='relu', input_shape=new_input)),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    TimeDistributed(Dropout(0.25)),
    
    TimeDistributed(Conv2D(128, (5, 5), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Conv2D(196, (3, 3), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Conv2D(256, (3, 3), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Conv2D(384, (3, 3), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Conv2D(896, (3, 3), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Flatten()),
    LSTM(256, activation='tanh'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='softmax')
])

optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)

history = model.fit(trainloader, epochs=EPOCHS, validation_data=validloader)

_, accuracy, top_5_accuracy = model.evaluate(testloader)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# Epoch 1/400
# /usr/lib/python3/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1739561646.598625   12030 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 65s 471ms/step - accuracy: 0.2258 - loss: 2.9978 - top-5-accuracy: 0.7863 - val_accuracy: 0.1000 - val_loss: 2.2005 - val_top-5-accuracy: 0.8342
# Epoch 2/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 448ms/step - accuracy: 0.2107 - loss: 2.6818 - top-5-accuracy: 0.7941 - val_accuracy: 0.1242 - val_loss: 2.4412 - val_top-5-accuracy: 0.7908
# Epoch 3/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 450ms/step - accuracy: 0.2701 - loss: 2.3935 - top-5-accuracy: 0.8222 - val_accuracy: 0.1975 - val_loss: 2.4538 - val_top-5-accuracy: 0.7833
# Epoch 4/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 449ms/step - accuracy: 0.3334 - loss: 2.1915 - top-5-accuracy: 0.8540 - val_accuracy: 0.2958 - val_loss: 2.0980 - val_top-5-accuracy: 0.8125
# Epoch 5/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 450ms/step - accuracy: 0.3596 - loss: 1.9950 - top-5-accuracy: 0.8913 - val_accuracy: 0.2175 - val_loss: 2.5197 - val_top-5-accuracy: 0.7925
# Epoch 6/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 451ms/step - accuracy: 0.4262 - loss: 1.7302 - top-5-accuracy: 0.9125 - val_accuracy: 0.3675 - val_loss: 1.7070 - val_top-5-accuracy: 0.9092
# Epoch 7/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.4992 - loss: 1.4980 - top-5-accuracy: 0.9388 - val_accuracy: 0.2525 - val_loss: 2.5621 - val_top-5-accuracy: 0.8842
# Epoch 8/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.5150 - loss: 1.4085 - top-5-accuracy: 0.9511 - val_accuracy: 0.3042 - val_loss: 2.3808 - val_top-5-accuracy: 0.8133
# Epoch 9/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.5646 - loss: 1.2813 - top-5-accuracy: 0.9576 - val_accuracy: 0.3567 - val_loss: 2.0088 - val_top-5-accuracy: 0.8642
# Epoch 10/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0
400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9998 - loss: 0.0015 - top-5-accuracy: 1.0000 - val_accuracy: 0.8858 - val_loss: 0.7719 - val_top-5-accuracy: 0.9925
# Epoch 350/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9983 - loss: 0.0026 - top-5-accuracy: 1.0000 - val_accuracy: 0.9042 - val_loss: 0.6391 - val_top-5-accuracy: 0.9917
# Epoch 351/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9999 - loss: 0.0014 - top-5-accuracy: 1.0000 - val_accuracy: 0.8958 - val_loss: 0.6592 - val_top-5-accuracy: 0.9958
# Epoch 352/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9989 - loss: 0.0030 - top-5-accuracy: 1.0000 - val_accuracy: 0.8900 - val_loss: 0.8242 - val_top-5-accuracy: 0.9867
# Epoch 353/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9990 - loss: 0.0031 - top-5-accuracy: 1.0000 - val_accuracy: 0.8858 - val_loss: 0.7452 - val_top-5-accuracy: 0.9983
# Epoch 354/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9979 - loss: 0.0060 - top-5-accuracy: 1.0000 - val_accuracy: 0.9050 - val_loss: 0.6657 - val_top-5-accuracy: 0.9850
# Epoch 355/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9998 - loss: 0.0017 - top-5-accuracy: 1.0000 - val_accuracy: 0.8692 - val_loss: 0.9899 - val_top-5-accuracy: 0.9867
# Epoch 356/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9987 - loss: 0.0055 - top-5-accuracy: 1.0000 - val_accuracy: 0.8933 - val_loss: 0.7358 - val_top-5-accuracy: 0.9875
# Epoch 357/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 1.0000 - loss: 0.0014 - top-5-accuracy: 1.0000 - val_accuracy: 0.8900 - val_loss: 0.7723 - val_top-5-accuracy: 0.9900
# Epoch 358/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9993 - loss: 0.0022 - top-5-accuracy: 1.0000 - val_accuracy: 0.8883 - val_loss: 0.8670 - val_top-5-accuracy: 0.9825
# Epoch 359/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9985 - loss: 0.0091 - top-5-accuracy: 1.0000 - val_accuracy: 0.8767 - val_loss: 0.7861 - val_top-5-accuracy: 0.9892
# Epoch 360/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9986 - loss: 0.0056 - top-5-accuracy: 1.0000 - val_accuracy: 0.8767 - val_loss: 1.0062 - val_top-5-accuracy: 0.9725
# Epoch 361/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9994 - loss: 0.0043 - top-5-accuracy: 1.0000 - val_accuracy: 0.8850 - val_loss: 0.8354 - val_top-5-accuracy: 0.9875
# Epoch 362/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9980 - loss: 0.0041 - top-5-accuracy: 1.0000 - val_accuracy: 0.8842 - val_loss: 0.8765 - val_top-5-accuracy: 0.9800
# Epoch 363/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9984 - loss: 0.0080 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.8786 - val_top-5-accuracy: 0.9842
# Epoch 364/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9993 - loss: 0.0039 - top-5-accuracy: 1.0000 - val_accuracy: 0.8883 - val_loss: 0.8297 - val_top-5-accuracy: 0.9833
# Epoch 365/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9976 - loss: 0.0074 - top-5-accuracy: 1.0000 - val_accuracy: 0.8817 - val_loss: 0.8346 - val_top-5-accuracy: 0.9875
# Epoch 366/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9992 - loss: 0.0026 - top-5-accuracy: 1.0000 - val_accuracy: 0.8900 - val_loss: 0.8825 - val_top-5-accuracy: 0.9783
# Epoch 367/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 1.0000 - loss: 0.0014 - top-5-accuracy: 1.0000 - val_accuracy: 0.8950 - val_loss: 0.8280 - val_top-5-accuracy: 0.9875
# Epoch 368/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 1.0000 - loss: 4.4637e-04 - top-5-accuracy: 1.0000 - val_accuracy: 0.9017 - val_loss: 0.7881 - val_top-5-accuracy: 0.9900
# Epoch 369/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9990 - loss: 0.0032 - top-5-accuracy: 1.0000 - val_accuracy: 0.8700 - val_loss: 0.8613 - val_top-5-accuracy: 0.9858
# Epoch 370/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9967 - loss: 0.0099 - top-5-accuracy: 1.0000 - val_accuracy: 0.8442 - val_loss: 1.1360 - val_top-5-accuracy: 0.9800
# Epoch 371/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9991 - loss: 0.0036 - top-5-accuracy: 1.0000 - val_accuracy: 0.8708 - val_loss: 0.8356 - val_top-5-accuracy: 0.9892
# Epoch 372/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 450ms/step - accuracy: 0.9936 - loss: 0.0157 - top-5-accuracy: 1.0000 - val_accuracy: 0.8658 - val_loss: 0.9529 - val_top-5-accuracy: 0.9925
# Epoch 373/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 451ms/step - accuracy: 0.9972 - loss: 0.0072 - top-5-accuracy: 1.0000 - val_accuracy: 0.8817 - val_loss: 0.7601 - val_top-5-accuracy: 0.9933
# Epoch 374/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 1.0000 - loss: 0.0018 - top-5-accuracy: 1.0000 - val_accuracy: 0.8942 - val_loss: 0.6780 - val_top-5-accuracy: 0.9950
# Epoch 375/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 1.0000 - loss: 0.0019 - top-5-accuracy: 1.0000 - val_accuracy: 0.8867 - val_loss: 0.7238 - val_top-5-accuracy: 0.9967
# Epoch 376/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 450ms/step - accuracy: 0.9999 - loss: 0.0011 - top-5-accuracy: 1.0000 - val_accuracy: 0.8933 - val_loss: 0.7711 - val_top-5-accuracy: 0.9908
# Epoch 377/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 451ms/step - accuracy: 0.9983 - loss: 0.0136 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.6425 - val_top-5-accuracy: 0.9975
# Epoch 378/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9992 - loss: 0.0028 - top-5-accuracy: 1.0000 - val_accuracy: 0.8900 - val_loss: 0.7425 - val_top-5-accuracy: 0.9917
# Epoch 379/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 450ms/step - accuracy: 0.9998 - loss: 0.0020 - top-5-accuracy: 1.0000 - val_accuracy: 0.9092 - val_loss: 0.5738 - val_top-5-accuracy: 0.9933
# Epoch 380/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 451ms/step - accuracy: 0.9984 - loss: 0.0070 - top-5-accuracy: 1.0000 - val_accuracy: 0.8817 - val_loss: 0.7181 - val_top-5-accuracy: 0.9983
# Epoch 381/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 449ms/step - accuracy: 1.0000 - loss: 0.0018 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.7931 - val_top-5-accuracy: 0.9925
# Epoch 382/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 450ms/step - accuracy: 0.9988 - loss: 0.0050 - top-5-accuracy: 0.9998 - val_accuracy: 0.8833 - val_loss: 0.7918 - val_top-5-accuracy: 0.9917
# Epoch 383/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 450ms/step - accuracy: 0.9990 - loss: 0.0028 - top-5-accuracy: 1.0000 - val_accuracy: 0.8683 - val_loss: 0.7611 - val_top-5-accuracy: 0.9983
# Epoch 384/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 451ms/step - accuracy: 0.9969 - loss: 0.0079 - top-5-accuracy: 1.0000 - val_accuracy: 0.8825 - val_loss: 0.7824 - val_top-5-accuracy: 0.9942
# Epoch 385/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9982 - loss: 0.0081 - top-5-accuracy: 0.9995 - val_accuracy: 0.8783 - val_loss: 0.8535 - val_top-5-accuracy: 0.9950
# Epoch 386/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9989 - loss: 0.0036 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.8422 - val_top-5-accuracy: 0.9967
# Epoch 387/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9993 - loss: 0.0018 - top-5-accuracy: 1.0000 - val_accuracy: 0.8908 - val_loss: 0.7707 - val_top-5-accuracy: 0.9992
# Epoch 388/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9997 - loss: 0.0015 - top-5-accuracy: 1.0000 - val_accuracy: 0.8842 - val_loss: 0.7971 - val_top-5-accuracy: 0.9942
# Epoch 389/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 450ms/step - accuracy: 0.9994 - loss: 0.0030 - top-5-accuracy: 1.0000 - val_accuracy: 0.9008 - val_loss: 0.6319 - val_top-5-accuracy: 0.9975
# Epoch 390/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 451ms/step - accuracy: 0.9999 - loss: 0.0011 - top-5-accuracy: 1.0000 - val_accuracy: 0.8892 - val_loss: 0.7437 - val_top-5-accuracy: 0.9983
# Epoch 391/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9995 - loss: 0.0018 - top-5-accuracy: 1.0000 - val_accuracy: 0.9025 - val_loss: 0.6220 - val_top-5-accuracy: 0.9975
# Epoch 392/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9985 - loss: 0.0028 - top-5-accuracy: 1.0000 - val_accuracy: 0.8892 - val_loss: 0.6377 - val_top-5-accuracy: 0.9975
# Epoch 393/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9988 - loss: 0.0031 - top-5-accuracy: 1.0000 - val_accuracy: 0.8692 - val_loss: 0.8887 - val_top-5-accuracy: 0.9883
# Epoch 394/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9992 - loss: 0.0030 - top-5-accuracy: 1.0000 - val_accuracy: 0.8158 - val_loss: 1.2845 - val_top-5-accuracy: 0.9675
# Epoch 395/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9980 - loss: 0.0056 - top-5-accuracy: 1.0000 - val_accuracy: 0.8908 - val_loss: 0.8077 - val_top-5-accuracy: 0.9917
# Epoch 396/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9997 - loss: 0.0020 - top-5-accuracy: 1.0000 - val_accuracy: 0.8883 - val_loss: 0.7362 - val_top-5-accuracy: 0.9975
# Epoch 397/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9980 - loss: 0.0050 - top-5-accuracy: 1.0000 - val_accuracy: 0.8808 - val_loss: 0.8220 - val_top-5-accuracy: 0.9917
# Epoch 398/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9984 - loss: 0.0145 - top-5-accuracy: 1.0000 - val_accuracy: 0.9000 - val_loss: 0.6976 - val_top-5-accuracy: 0.9958
# Epoch 399/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 1.0000 - loss: 0.0017 - top-5-accuracy: 1.0000 - val_accuracy: 0.8925 - val_loss: 0.7233 - val_top-5-accuracy: 0.9975
# Epoch 400/400
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 1.0000 - loss: 9.5599e-04 - top-5-accuracy: 1.0000 - val_accuracy: 0.8842 - val_loss: 0.7929 - val_top-5-accuracy: 0.9983
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8931 - loss: 0.7555 - top-5-accuracy: 0.9947
# Test accuracy: 88.08%
# Test top 5 accuracy: 99.33%

# %%
# Plotting both
plt.figure(figsize=(10, 6))
plt.plot(np.log(history.history['loss'][9:]), label='Training')
plt.plot(np.log(history.history['val_loss'][9:]), label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Step 1: Get predictions from the trained model
y_pred_probs = model.predict(testloader)  # Predict probabilities for each class

# Step 2: Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Step 3: Get true labels
y_true = np.concatenate([y for x, y in testloader], axis=0)

# Step 4: Generate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Making each entry a percentage of the row sum
cm_percentage = np.round(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], 3)

# Step 5: Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm_percentage, display_labels=range(7))
fig, ax = plt.subplots(figsize=(10, 8)) 
disp.plot(cmap=plt.cm.Blues, ax=ax, values_format='.3f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()  

plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step
# 2025-02-15 01:29:23.215488: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
model.save_weights('LSTM_alt_400.weights.h5')
