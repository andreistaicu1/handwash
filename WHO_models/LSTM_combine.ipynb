# %%
# !pip install "numpy<2.0.0"
# Then restart terminal
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy<2.0.0
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 126.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# Successfully installed numpy-1.26.4

# %%
# !pip install -qq medmnist
# !pip install -qq av
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/ubuntu/.local/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from opencv-python) (1.26.4)

# %%
import sys
sys.path.append('/home/ubuntu/.lambda/lib/python3.10/site-packages')

# %%
import os
import cv2
import numpy as np
import tensorflow as tf  # for data preprocessing only
import keras
import av
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# 2024-12-16 20:03:20.350240: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-16 20:03:20.362283: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-16 20:03:20.376835: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-16 20:03:20.381148: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-16 20:03:20.391936: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
DATA_DIR = 'HandWashDataset'

CLASSES = ['Step_1', 'Step_2_Left', 'Step_2_Right', 'Step_3', 
           'Step_4_Left', 'Step_4_Right', 'Step_5_Left', 'Step_5_Right', 
           'Step_6_Left', 'Step_6_Right', 'Step_7_Left', 'Step_7_Right']

LABELS_TO_ID = { 'Step_1' : 0, 'Step_2_Left' : 1, 'Step_2_Right' : 1, 
                'Step_3' : 2, 'Step_4_Left' : 3, 'Step_4_Right' : 3, 
                'Step_5_Left' : 4, 'Step_5_Right' : 4, 'Step_6_Left' : 5,
                'Step_6_Right' : 5, 'Step_7_Left' : 6, 'Step_7_Right' : 6}

ACTUAL_CLASSES = [1, 2, 3, 4, 5, 6, 7]

# LABELS_TO_ID = { label : i for i, label in enumerate(CLASSES) }

TEST_SIZE = 0.2
VAL_SIZE = 0.2
DATASET_SEED = 81

FRAME_SIZE = (360, 240)
SCALE = 255.0
CLIP_LENGTH = 60 # 120 runs into errors

INPUT_SHAPE = (210, 270, 1) # coordinates are inverted for some reason
NUM_FRAMES = 3

# TRAINING
BATCH_SIZE = 32 # down from 64 because of frame size
NUM_CLASSES = len(ACTUAL_CLASSES)
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5
EPOCHS = 100

# %%
def prepare_dataset(data_dir, classes, test_size=TEST_SIZE, val_size=VAL_SIZE, random_state=DATASET_SEED):
    video_lengths = []
    for class_name in classes:
        class_dir = os.path.join(data_dir, class_name)
        videos = os.listdir(class_dir)
        for video_file in videos:
            if os.path.isdir(video_file):
                continue
            video_path = os.path.join(class_dir, video_file)
            video_reader = cv2.VideoCapture(video_path)
            frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
            video_lengths.append((class_name, video_path, frames_count))
            video_reader.release()

    train_videos, test_val_videos = train_test_split(video_lengths, test_size=test_size+val_size, random_state=random_state)
    val_videos, test_videos = train_test_split(test_val_videos, test_size=test_size/(test_size+val_size), random_state=random_state)

    return train_videos, val_videos, test_videos

# %%
def read_video_pyav(container, indices, new_size = FRAME_SIZE, scale=SCALE):
    '''Decode the video with PyAV decoder.
    Args:
        container (`av.container.input.InputContainer`): PyAV container.
        indices (`List[int]`): List of frame indices to decode.
    Returns:
        result (np.ndarray): np array of decoded frames of shape (num_frames, height, width, 3).'''
    frames = []
    container.seek(0)
    start_index = indices[0]
    end_index = indices[-1]
    for i, frame in enumerate(container.decode(video=0)):
        if i > end_index:
            break
        if i >= start_index and i in indices:
            new_frame = frame.to_ndarray(format="rgb24")
            new_frame = cv2.cvtColor(new_frame, cv2.COLOR_RGB2GRAY)
            new_frame = new_frame / scale
            new_frame = cv2.resize(new_frame, new_size)
            frames.append(new_frame)
    return np.stack(frames)

def sample_frame_indices(frame_sample_rate, seg_len, clip_len=CLIP_LENGTH):
    '''Sample a given number of frame indices from the video.
    Args:
        clip_len (`int`): Total number of frames to sample.
        frame_sample_rate (`int`): Sample every n-th frame.
        seg_len (`int`): Maximum allowed index of sample's last frame.
    Returns:
        indices (`List[int]`): List of sampled frame indices'''
    converted_len = int(clip_len * frame_sample_rate)
    # end_idx = np.random.randint(converted_len, seg_len)
    end_idx = seg_len # Always picking the last CLIP_LENGTH many frames
    start_idx = end_idx - converted_len
    indices = np.linspace(start_idx, end_idx, num=clip_len)
    indices = np.clip(indices, start_idx, end_idx - 1).astype(np.int64)
    return indices

def download_and_prepare_dataset(video_directories: list):
    """Utility function to download dataset
    Arguments:
        list of addresses of videos
    Returns:
        list of videos, each of different dimension"""
    np_videos = []
    for address in video_directories:
        vid_container = av.open(address)
        vid_indices = sample_frame_indices(frame_sample_rate=1, seg_len=vid_container.streams.video[0].frames)
        np_videos.append(read_video_pyav(container=vid_container, indices=vid_indices))
    return np_videos

def preprocess_dataset(list_of_videos, list_of_labels, new_size=FRAME_SIZE, clip_len=CLIP_LENGTH):
    """Normalize and resize the dataset"""
    clips = clip_len // NUM_FRAMES
    resized_list = np.zeros((len(list_of_videos) * clips, NUM_FRAMES, FRAME_SIZE[1], FRAME_SIZE[0]), dtype=np.float32)
    resized_labels = np.zeros((len(list_of_videos) * clips), dtype = np.float32)
    for i, video in enumerate(list_of_videos):
        for j, frame in enumerate(video):
            clip_num = ((i * CLIP_LENGTH) + j) // 3
            if j % 3 == 0:
                resized_labels[clip_num] = list_of_labels[i]
            resized_list[clip_num][j % 3] = frame
            
    return (resized_list, resized_labels)

# %%
train_info, val_info, test_info = prepare_dataset(DATA_DIR, CLASSES)

train_addr = [info[1] for info in train_info]
train_names = [LABELS_TO_ID[info[0]] for info in train_info]

val_addr = [info[1] for info in val_info]
val_names = [LABELS_TO_ID[info[0]] for info in val_info]

test_addr = [info[1] for info in test_info]
test_names = [LABELS_TO_ID[info[0]] for info in test_info]

# %%
train_videos, train_labels = preprocess_dataset(download_and_prepare_dataset(train_addr), train_names)
print("done with train")
val_videos, val_labels = preprocess_dataset(download_and_prepare_dataset(val_addr), val_names)
print("done with val")
test_videos, test_labels = preprocess_dataset(download_and_prepare_dataset(test_addr), test_names)
# Out:
# done with train
# done with val

# %%
def preprocess(frame: tf.Tensor, label: tf.Tensor):
    """Preprocess the frames tensors and parse the labels."""
    frame = frame[..., tf.newaxis]
    frame = tf.image.random_crop(frame, size=(NUM_FRAMES, INPUT_SHAPE[0], INPUT_SHAPE[1], INPUT_SHAPE[2]))
    frame = tf.image.random_flip_up_down(frame)
    frame = tf.image.random_brightness(frame, 0.2)
    return frame, label

def prepare_dataloader(
    videos: np.ndarray,
    labels: np.ndarray,
    loader_type: str = "train",
    batch_size: int = BATCH_SIZE,
):
    """Utility function to prepare the dataloader."""
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    return dataloader

# %%
trainloader = prepare_dataloader(train_videos, train_labels, "train")
validloader = prepare_dataloader(val_videos, val_labels, "valid")
testloader = prepare_dataloader(test_videos, test_labels, "test")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734379926.313637    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734379926.357869    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734379926.361574    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734379926.367235    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734379926.370896    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734379926.374252    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734379926.508477    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734379926.509964    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734379926.511356    4071 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-16 20:12:06.512610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20732 MB memory:  -> device: 0, name: NVIDIA A10, pci bus id: 0000:05:00.0, compute capability: 8.6

# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, TimeDistributed, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical

# %%
print(NUM_CLASSES)
# Out:
# 7

# %%
new_input = (NUM_FRAMES, INPUT_SHAPE[0], INPUT_SHAPE[1], INPUT_SHAPE[2])

model = Sequential([
    TimeDistributed(Conv2D(48, (7, 7), activation='relu', input_shape=new_input)),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    TimeDistributed(Dropout(0.25)),
    
    TimeDistributed(Conv2D(128, (5, 5), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Conv2D(196, (3, 3), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Conv2D(256, (3, 3), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Conv2D(384, (3, 3), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Conv2D(896, (3, 3), activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D((2, 2))),
    
    TimeDistributed(Flatten()),
    LSTM(256, activation='tanh'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='softmax')
])

optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)

history = model.fit(trainloader, epochs=EPOCHS, validation_data=validloader)

_, accuracy, top_5_accuracy = model.evaluate(testloader)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# Epoch 1/100
# /usr/lib/python3/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-12-16 20:12:20.002050: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90400
# W0000 00:00:1734379940.148600   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.178957   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.182594   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.209094   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.219030   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.221018   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.223836   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.225326   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.227041   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.229320   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.234823   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.241435   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.243910   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.246424   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.254738   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.269897   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.279435   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.288506   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.292297   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379940.301763   14051 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.737245   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.742099   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.746805   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.752422   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.756421   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.762017   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.767595   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.772050   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.776215   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.781221   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.786362   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.790715   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.795042   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.799285   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.804773   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.810575   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.817979   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.825804   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.832470   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.841501   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.849865   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.855505   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.864939   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.872292   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.880950   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.891083   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.901345   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.911092   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.921813   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.932103   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.943240   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.953203   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.962781   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.975026   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379941.990477   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.012250   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.054126   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.056172   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.059323   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.061589   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.063847   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.066038   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.068062   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.070371   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.072782   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.075017   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.077267   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.079481   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.081855   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.084362   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.086845   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.091203   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.094251   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.097320   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.099610   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.102863   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.105877   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.109283   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.113742   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.117330   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.121484   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.125270   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.129424   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.133732   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.137451   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.141819   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.146635   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.151962   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942.157207   14041 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1734379942
100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9631 - loss: 0.1140 - top-5-accuracy: 1.0000 - val_accuracy: 0.8458 - val_loss: 0.5143 - val_top-5-accuracy: 0.9858
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9684 - loss: 0.1059 - top-5-accuracy: 0.9999 - val_accuracy: 0.8400 - val_loss: 0.5603 - val_top-5-accuracy: 0.9825
# Epoch 36/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9600 - loss: 0.1190 - top-5-accuracy: 0.9998 - val_accuracy: 0.8092 - val_loss: 0.7380 - val_top-5-accuracy: 0.9742
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9728 - loss: 0.0982 - top-5-accuracy: 1.0000 - val_accuracy: 0.7517 - val_loss: 1.0532 - val_top-5-accuracy: 0.9775
# Epoch 38/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9633 - loss: 0.1137 - top-5-accuracy: 0.9991 - val_accuracy: 0.8275 - val_loss: 0.5985 - val_top-5-accuracy: 0.9875
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9639 - loss: 0.1161 - top-5-accuracy: 0.9992 - val_accuracy: 0.8117 - val_loss: 0.6981 - val_top-5-accuracy: 0.9783
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9813 - loss: 0.0705 - top-5-accuracy: 0.9997 - val_accuracy: 0.8508 - val_loss: 0.5708 - val_top-5-accuracy: 0.9800
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9793 - loss: 0.0740 - top-5-accuracy: 1.0000 - val_accuracy: 0.8508 - val_loss: 0.6537 - val_top-5-accuracy: 0.9708
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9810 - loss: 0.0609 - top-5-accuracy: 1.0000 - val_accuracy: 0.8275 - val_loss: 0.6822 - val_top-5-accuracy: 0.9858
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9751 - loss: 0.0742 - top-5-accuracy: 1.0000 - val_accuracy: 0.8292 - val_loss: 0.6102 - val_top-5-accuracy: 0.9842
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9801 - loss: 0.0680 - top-5-accuracy: 1.0000 - val_accuracy: 0.8558 - val_loss: 0.5734 - val_top-5-accuracy: 0.9733
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9729 - loss: 0.0774 - top-5-accuracy: 1.0000 - val_accuracy: 0.7825 - val_loss: 0.8359 - val_top-5-accuracy: 0.9775
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9723 - loss: 0.0758 - top-5-accuracy: 1.0000 - val_accuracy: 0.8392 - val_loss: 0.6180 - val_top-5-accuracy: 0.9808
# Epoch 47/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9851 - loss: 0.0518 - top-5-accuracy: 1.0000 - val_accuracy: 0.8317 - val_loss: 0.7933 - val_top-5-accuracy: 0.9733
# Epoch 48/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9791 - loss: 0.0709 - top-5-accuracy: 1.0000 - val_accuracy: 0.8267 - val_loss: 0.6485 - val_top-5-accuracy: 0.9758
# Epoch 49/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9819 - loss: 0.0648 - top-5-accuracy: 0.9999 - val_accuracy: 0.8350 - val_loss: 0.7070 - val_top-5-accuracy: 0.9808
# Epoch 50/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9747 - loss: 0.0813 - top-5-accuracy: 1.0000 - val_accuracy: 0.7767 - val_loss: 0.8371 - val_top-5-accuracy: 0.9892
# Epoch 51/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9726 - loss: 0.0904 - top-5-accuracy: 1.0000 - val_accuracy: 0.8408 - val_loss: 0.5355 - val_top-5-accuracy: 0.9917
# Epoch 52/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9820 - loss: 0.0662 - top-5-accuracy: 1.0000 - val_accuracy: 0.7583 - val_loss: 0.8637 - val_top-5-accuracy: 0.9783
# Epoch 53/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9787 - loss: 0.0655 - top-5-accuracy: 1.0000 - val_accuracy: 0.8467 - val_loss: 0.5815 - val_top-5-accuracy: 0.9858
# Epoch 54/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9847 - loss: 0.0578 - top-5-accuracy: 1.0000 - val_accuracy: 0.8667 - val_loss: 0.6264 - val_top-5-accuracy: 0.9808
# Epoch 55/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9795 - loss: 0.0619 - top-5-accuracy: 0.9999 - val_accuracy: 0.8458 - val_loss: 0.6941 - val_top-5-accuracy: 0.9742
# Epoch 56/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9847 - loss: 0.0520 - top-5-accuracy: 1.0000 - val_accuracy: 0.8433 - val_loss: 0.6289 - val_top-5-accuracy: 0.9883
# Epoch 57/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9862 - loss: 0.0487 - top-5-accuracy: 0.9997 - val_accuracy: 0.8583 - val_loss: 0.6117 - val_top-5-accuracy: 0.9817
# Epoch 58/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9813 - loss: 0.0608 - top-5-accuracy: 0.9998 - val_accuracy: 0.8242 - val_loss: 0.8189 - val_top-5-accuracy: 0.9783
# Epoch 59/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9894 - loss: 0.0403 - top-5-accuracy: 1.0000 - val_accuracy: 0.8608 - val_loss: 0.6370 - val_top-5-accuracy: 0.9875
# Epoch 60/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9927 - loss: 0.0319 - top-5-accuracy: 1.0000 - val_accuracy: 0.8633 - val_loss: 0.5855 - val_top-5-accuracy: 0.9825
# Epoch 61/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9885 - loss: 0.0379 - top-5-accuracy: 1.0000 - val_accuracy: 0.8350 - val_loss: 0.6524 - val_top-5-accuracy: 0.9958
# Epoch 62/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9814 - loss: 0.0472 - top-5-accuracy: 1.0000 - val_accuracy: 0.7758 - val_loss: 1.0949 - val_top-5-accuracy: 0.9717
# Epoch 63/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9821 - loss: 0.0534 - top-5-accuracy: 1.0000 - val_accuracy: 0.8408 - val_loss: 0.7273 - val_top-5-accuracy: 0.9767
# Epoch 64/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9855 - loss: 0.0452 - top-5-accuracy: 1.0000 - val_accuracy: 0.8350 - val_loss: 0.7990 - val_top-5-accuracy: 0.9825
# Epoch 65/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9876 - loss: 0.0414 - top-5-accuracy: 1.0000 - val_accuracy: 0.8358 - val_loss: 0.7293 - val_top-5-accuracy: 0.9875
# Epoch 66/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9897 - loss: 0.0351 - top-5-accuracy: 1.0000 - val_accuracy: 0.8233 - val_loss: 0.7241 - val_top-5-accuracy: 0.9800
# Epoch 67/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9888 - loss: 0.0415 - top-5-accuracy: 1.0000 - val_accuracy: 0.7950 - val_loss: 0.7542 - val_top-5-accuracy: 0.9942
# Epoch 68/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9829 - loss: 0.0515 - top-5-accuracy: 1.0000 - val_accuracy: 0.8750 - val_loss: 0.5426 - val_top-5-accuracy: 0.9867
# Epoch 69/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9902 - loss: 0.0371 - top-5-accuracy: 1.0000 - val_accuracy: 0.8483 - val_loss: 0.6094 - val_top-5-accuracy: 0.9900
# Epoch 70/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9769 - loss: 0.0691 - top-5-accuracy: 1.0000 - val_accuracy: 0.8375 - val_loss: 0.8501 - val_top-5-accuracy: 0.9742
# Epoch 71/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9820 - loss: 0.0494 - top-5-accuracy: 1.0000 - val_accuracy: 0.8467 - val_loss: 0.7189 - val_top-5-accuracy: 0.9875
# Epoch 72/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9929 - loss: 0.0261 - top-5-accuracy: 1.0000 - val_accuracy: 0.8600 - val_loss: 0.5845 - val_top-5-accuracy: 0.9892
# Epoch 73/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9943 - loss: 0.0265 - top-5-accuracy: 0.9998 - val_accuracy: 0.8683 - val_loss: 0.5619 - val_top-5-accuracy: 0.9983
# Epoch 74/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9899 - loss: 0.0331 - top-5-accuracy: 1.0000 - val_accuracy: 0.8550 - val_loss: 0.7012 - val_top-5-accuracy: 0.9883
# Epoch 75/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9907 - loss: 0.0412 - top-5-accuracy: 1.0000 - val_accuracy: 0.8575 - val_loss: 0.5795 - val_top-5-accuracy: 0.9925
# Epoch 76/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9862 - loss: 0.0399 - top-5-accuracy: 1.0000 - val_accuracy: 0.8100 - val_loss: 0.7388 - val_top-5-accuracy: 0.9900
# Epoch 77/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9880 - loss: 0.0406 - top-5-accuracy: 0.9996 - val_accuracy: 0.8592 - val_loss: 0.6239 - val_top-5-accuracy: 0.9933
# Epoch 78/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9872 - loss: 0.0436 - top-5-accuracy: 1.0000 - val_accuracy: 0.8642 - val_loss: 0.6123 - val_top-5-accuracy: 0.9942
# Epoch 79/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9933 - loss: 0.0292 - top-5-accuracy: 1.0000 - val_accuracy: 0.8417 - val_loss: 0.8127 - val_top-5-accuracy: 0.9742
# Epoch 80/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 82s 450ms/step - accuracy: 0.9911 - loss: 0.0332 - top-5-accuracy: 1.0000 - val_accuracy: 0.8633 - val_loss: 0.6638 - val_top-5-accuracy: 0.9883
# Epoch 81/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 452ms/step - accuracy: 0.9960 - loss: 0.0175 - top-5-accuracy: 1.0000 - val_accuracy: 0.8692 - val_loss: 0.6867 - val_top-5-accuracy: 0.9858
# Epoch 82/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9904 - loss: 0.0280 - top-5-accuracy: 1.0000 - val_accuracy: 0.8658 - val_loss: 0.6808 - val_top-5-accuracy: 0.9917
# Epoch 83/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9917 - loss: 0.0226 - top-5-accuracy: 1.0000 - val_accuracy: 0.8483 - val_loss: 0.7737 - val_top-5-accuracy: 0.9908
# Epoch 84/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9938 - loss: 0.0221 - top-5-accuracy: 1.0000 - val_accuracy: 0.8725 - val_loss: 0.6212 - val_top-5-accuracy: 0.9950
# Epoch 85/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9882 - loss: 0.0333 - top-5-accuracy: 1.0000 - val_accuracy: 0.8483 - val_loss: 0.8185 - val_top-5-accuracy: 0.9925
# Epoch 86/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9872 - loss: 0.0333 - top-5-accuracy: 1.0000 - val_accuracy: 0.8100 - val_loss: 0.9791 - val_top-5-accuracy: 0.9942
# Epoch 87/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9861 - loss: 0.0519 - top-5-accuracy: 1.0000 - val_accuracy: 0.8733 - val_loss: 0.6012 - val_top-5-accuracy: 0.9942
# Epoch 88/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9902 - loss: 0.0306 - top-5-accuracy: 1.0000 - val_accuracy: 0.8650 - val_loss: 0.7274 - val_top-5-accuracy: 0.9942
# Epoch 89/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9922 - loss: 0.0254 - top-5-accuracy: 1.0000 - val_accuracy: 0.8892 - val_loss: 0.5834 - val_top-5-accuracy: 0.9942
# Epoch 90/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9918 - loss: 0.0315 - top-5-accuracy: 1.0000 - val_accuracy: 0.8683 - val_loss: 0.5815 - val_top-5-accuracy: 0.9942
# Epoch 91/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9973 - loss: 0.0163 - top-5-accuracy: 1.0000 - val_accuracy: 0.8733 - val_loss: 0.6448 - val_top-5-accuracy: 0.9892
# Epoch 92/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9888 - loss: 0.0357 - top-5-accuracy: 1.0000 - val_accuracy: 0.8408 - val_loss: 0.8299 - val_top-5-accuracy: 0.9867
# Epoch 93/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9916 - loss: 0.0290 - top-5-accuracy: 1.0000 - val_accuracy: 0.8700 - val_loss: 0.6372 - val_top-5-accuracy: 0.9850
# Epoch 94/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9943 - loss: 0.0172 - top-5-accuracy: 1.0000 - val_accuracy: 0.8708 - val_loss: 0.5294 - val_top-5-accuracy: 0.9950
# Epoch 95/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9945 - loss: 0.0234 - top-5-accuracy: 1.0000 - val_accuracy: 0.8575 - val_loss: 0.6358 - val_top-5-accuracy: 0.9925
# Epoch 96/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9952 - loss: 0.0212 - top-5-accuracy: 1.0000 - val_accuracy: 0.8783 - val_loss: 0.5260 - val_top-5-accuracy: 0.9992
# Epoch 97/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9955 - loss: 0.0250 - top-5-accuracy: 1.0000 - val_accuracy: 0.8442 - val_loss: 0.8245 - val_top-5-accuracy: 0.9908
# Epoch 98/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9904 - loss: 0.0313 - top-5-accuracy: 1.0000 - val_accuracy: 0.8333 - val_loss: 0.9182 - val_top-5-accuracy: 0.9842
# Epoch 99/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9901 - loss: 0.0308 - top-5-accuracy: 1.0000 - val_accuracy: 0.8567 - val_loss: 0.6836 - val_top-5-accuracy: 0.9933
# Epoch 100/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 51s 453ms/step - accuracy: 0.9887 - loss: 0.0316 - top-5-accuracy: 1.0000 - val_accuracy: 0.8800 - val_loss: 0.5155 - val_top-5-accuracy: 0.9967
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8962 - loss: 0.4482 - top-5-accuracy: 0.9992
# Test accuracy: 87.92%
# Test top 5 accuracy: 99.92%

# %%
# Plotting both
plt.figure(figsize=(10, 6))
plt.plot(np.log(history.history['loss'][9:]), label='Training')
plt.plot(np.log(history.history['val_loss'][9:]), label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Step 1: Get predictions from the trained model
y_pred_probs = model.predict(testloader)  # Predict probabilities for each class

# Step 2: Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Step 3: Get true labels
y_true = np.concatenate([y for x, y in testloader], axis=0)

# Step 4: Generate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Making each entry a percentage of the row sum
cm_percentage = np.round(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], 3)

# Step 5: Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm_percentage, display_labels=range(7))
fig, ax = plt.subplots(figsize=(10, 8)) 
disp.plot(cmap=plt.cm.Blues, ax=ax, values_format='.3f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()  

plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step
# 2024-12-16 21:55:35.257495: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
model.save_weights('LSTM_alt.weights.h5')
